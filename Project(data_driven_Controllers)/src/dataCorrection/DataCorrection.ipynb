# %%
import pandas as ps

# %%
data = ps.read_csv("C:/Users/wvx67826/git/AIPID_Cryostat/src/data/testData/EM_LS336_Openloop_heaterStep=5_first.dat")

# %%
data
# Out:
#             Time(s)  SetTemp(K)  Temp(K)  HeatPower      P     I    D
# 0      1.670519e+09        80.0  127.527        0.0  130.0  50.0  0.0
# 1      1.670519e+09        80.0  127.540        0.0  130.0  50.0  0.0
# 2      1.670519e+09        80.0  127.546        0.0  130.0  50.0  0.0
# 3      1.670519e+09        80.0  127.548        0.0  130.0  50.0  0.0
# 4      1.670519e+09        80.0  127.542        0.0  130.0  50.0  0.0
# ...             ...         ...      ...        ...    ...   ...  ...
# 12211  1.670581e+09        80.0  335.430       30.0  130.0  50.0  0.0
# 12212  1.670581e+09        80.0  335.459       30.0  130.0  50.0  0.0
# 12213  1.670581e+09        80.0  335.495       30.0  130.0  50.0  0.0
# 12214  1.670581e+09        80.0  335.538       30.0  130.0  50.0  0.0
# 12215  1.670581e+09        80.0  335.495       30.0  130.0  50.0  0.0
#
# [12216 rows x 7 columns]

# %%
data['I'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12211    False
# 12212    False
# 12213    False
# 12214    False
# 12215    False
# Name: I, Length: 12216, dtype: bool

# %%
data2 = data.dropna()

# %%
data2['I'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12211    False
# 12212    False
# 12213    False
# 12214    False
# 12215    False
# Name: I, Length: 12193, dtype: bool

# %%
data3 = data2.drop(data2[data2.HeatPower>100].index)

# %%
data3
# Out:
#             Time(s)  SetTemp(K)  Temp(K)  HeatPower      P     I    D
# 0      1.670519e+09        80.0  127.527        0.0  130.0  50.0  0.0
# 1      1.670519e+09        80.0  127.540        0.0  130.0  50.0  0.0
# 2      1.670519e+09        80.0  127.546        0.0  130.0  50.0  0.0
# 3      1.670519e+09        80.0  127.548        0.0  130.0  50.0  0.0
# 4      1.670519e+09        80.0  127.542        0.0  130.0  50.0  0.0
# ...             ...         ...      ...        ...    ...   ...  ...
# 12211  1.670581e+09        80.0  335.430       30.0  130.0  50.0  0.0
# 12212  1.670581e+09        80.0  335.459       30.0  130.0  50.0  0.0
# 12213  1.670581e+09        80.0  335.495       30.0  130.0  50.0  0.0
# 12214  1.670581e+09        80.0  335.538       30.0  130.0  50.0  0.0
# 12215  1.670581e+09        80.0  335.495       30.0  130.0  50.0  0.0
#
# [12176 rows x 7 columns]

# %%
data3.to_csv("C:/Users/wvx67826/Desktop/PID//EM_LS336_Openloop_heaterStep=5_first.dat")
